# %%
# import dependencies
import json
import gmaps
import requests

from config import gkey

base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

# Set parameters to search for a hotel
location = '33.7333, 135.9833'
params = {
    'location': location,
    'radius': 5000,
    'types': 'lodging',
    'key': gkey
}

# make a request and get the JSON data from the search
hotels = requests.get(base_url, params).json()
print(json.dumps(response, indent=4))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEA2hLUNORqXixxo0c40i80Dkw7Jd2C5r0LAl-GMsxrvlsaItq0Kc8GsEjEC7ZnXXDf9fRgf8JjIRYL-FxxkT9KFpllL7l3JhmkWb1DOZxmnsEnXAsMlyc_DOvJ6DKKrXkffiD1lbEzeI1YBDPGoW3l-jF-xWmHaNfXwevEh0o7xDpu3UMYlvWFaLBzJBk-IAN4iuKBN_1TSe94IrvyWqMBg5sUS5_FDRF4A8FkCOn33RKbvQCjcZmo9_LUSUoBt4Xk-igRuPZxIF8ppn8zI_GuMJLlCpBPtN7leJdMqp3xDCuu1LVKKHJHMsIT3jDxss2C378yi1Vx2Smkn55mEXu4SMwMmfhdD3hjSS0d-8RV6ZFR3wLhgrvyKk_JVrr6yWebxQXYN4HV_IbijYUBNfS-EOugA8WYj493ZSXwLmnLC0VSJduYojX0J",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7227281,
#                     "lng": 135.9915719
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.72407533029151,
#                         "lng": 135.9930587802915
#                     },
#                     "southwest": {
# ...

# %%
# the number of found hotels
len(hotels['results'])
# Out:
# 20

# %%
# get the name and address of the first found hotel
hotel_name = response['results'][0]['name']
hotel_address = response['results'][0]['vicinity']
print(hotel_name)
print(hotel_address)
# Out:
# Shingu UI Hotel
# Shingu Ui Hotel, 3-12 Inosawa, Shingu
