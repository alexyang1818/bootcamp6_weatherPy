# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=1500)
lngs = np.random.uniform(-180,180,size=1500)
lat_lngs = zip(lats,lngs)
coordinates = list(lat_lngs)   # unpack. zipped tuple is removed once unpacked.

# %%
from citipy import citipy
for coordinate in coordinates:
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name, 
    #     citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
    pass

# %%
# create a list to hold cities
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # if the found city is unique, then we add it to the cities list
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 594

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
# import the datetime module
from datetime import datetime

# import the requests library
import requests

# import the API key
from config import weather_api_key

# starting URL for Weather Map API call.
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=' + weather_api_key

# %%
# create an empty list to hold the weather data
city_data = []
# print the beginning of the logging.
print('Beginning Data Retrieval    ')
print('----------------------------')

# create counters
record_count = 1
set_count = 1

# loop through all the cities in out list
for i, city in enumerate(cities):

    # group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        record_count = 1
        set_count += 1
    # create endpoint URL with each city
    city_url = url + '&q=' + city.replace(' ', '+')
    # log the URL, record and set numbers and the city
    print(f'Processing record {record_count} of set {set_count} | {city}')
    # add 1 to record_count
    record_count += 1

    # try-except
    try:
        # parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        #city_name = city_weather['name']
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds= city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        # convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # append info into the city_data list
        city_data.append({'City': city,
                          'Lat': city_lat, 
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Date': city_date})
    except:
        print('City not found. Skipping ' + city)
        pass

# indicate that data loading is complete.
print('---------------------------')
print('Data retrieval complete    ')
print('---------------------------')
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing record 1 of set 1 | grindavik
# Processing record 2 of set 1 | taolanaro
# City not found. Skipping taolanaro
# Processing record 3 of set 1 | bhag
# Processing record 4 of set 1 | atuona
# Processing record 5 of set 1 | novomyrhorod
# Processing record 6 of set 1 | vaini
# Processing record 7 of set 1 | yellowknife
# Processing record 8 of set 1 | hobart
# Processing record 9 of set 1 | ponnani
# Processing record 10 of set 1 | kaili
# Processing record 11 of set 1 | eyl
# Processing record 12 of set 1 | sao joao da barra
# Processing record 13 of set 1 | cangzhou
# Processing record 14 of set 1 | thompson
# Processing record 15 of set 1 | butaritari
# Processing record 16 of set 1 | rikitea
# Processing record 17 of set 1 | ancud
# Processing record 18 of set 1 | aljezur
# Processing record 19 of set 1 | mataura
# Processing record 20 of set 1 | jamestown
# Processing record 21 of set 1 | toliary
# City not found. Skipping toliary
# Processing record 22 of set 1 | sakakah
# Processing record 23 of set 1 | albany
# Processing record 24 of set 1 | polunochnoye
# Processing record 25 of set 1 | talnakh
# Processing record 26 of set 1 | lufilufi
# Processing record 27 of set 1 | montepuez
# Processing record 28 of set 1 | punta arenas
# Processing record 29 of set 1 | fortuna
# Processing record 30 of set 1 | castro
# Processing record 31 of set 1 | bogande
# Processing record 32 of set 1 | barrow
# Processing record 33 of set 1 | bredasdorp
# Processing record 34 of set 1 | upernavik
# Processing record 35 of set 1 | lixourion
# Processing record 36 of set 1 | bireun
# Processing record 37 of set 1 | tiksi
# Processing record 38 of set 1 | khon buri
# Processing record 39 of set 1 | avarua
# Processing record 40 of set 1 | grand river south east
# City not found. Skipping grand river south east
# Processing record 41 of set 1 | vaitupu
# City not found. Skipping vaitupu
# Processing record 42 of set 1 | sao filipe
# Processing record 43 of set 1 | lompoc
# Processing record 44 of set 1 | ahipara
# Processing record 45 of set 1 | toktogul
# Processing record 46 of set 1 | inuvik
# Processing record 47 of set 1 | samusu
# City not found. Skipping samusu
# Processing record 48 of set 1 | jeluko
# City not found. Skipping jeluko
# Processing record 49 of set 1 | cherskiy
# Processing record 50 of set 1 | aitape
# Processing record 1 of set 2 | kaitangata
# Processing record 2 of set 2 | cape town
# Processing record 3 of set 2 | ayna
# Processing record 4 of set 2 | gejiu
# Processing record 5 of set 2 | conceicao do araguaia
# Processing record 6 of set 2 | nanortalik
# Processing record 7 of set 2 | illoqqortoormiut
# City not found. Skipping illoqqortoormiut
# Processing record 8 of set 2 | qaanaaq
# Processing record 9 of set 2 | victoria
# Processing record 10 of set 2 | port alfred
# Processing record 11 of set 2 | hermanus
# Processing record 12 of set 2 | airai
# Processing record 13 of set 2 | lebu
# Processing record 14 of set 2 | kashary
# Processing record 15 of set 2 | mar del plata
# Processing record 16 of set 2 | yulara
# Processing record 17 of set 2 | ushuaia
# Processing record 18 of set 2 | kazalinsk
# City not found. Skipping kazalinsk
# Processing record 19 of set 2 | tsihombe
# City not found. Skipping tsihombe
# Processing record 20 of set 2 | towada
# Processing record 21 of set 2 | iqaluit
# Processing record 22 of set 2 | urdzhar
# City not found. Skipping urdzhar
# Processing record 23 of set 2 | puerto ayora
# Processing record 24 of set 2 | san miguel
# Processing record 25 of set 2 | kahului
# Processing record 26 of set 2 | chanthaburi
# Processing record 27 of set 2 | nago
# Processing record 28 of set 2 | port elizabeth
# Processing record 29 of set 2 | erdenet
# Processing record 30 of set 2 | egvekinot
# Processing record 31 of set 2 | carnarvon
# Processing record 32 of set 2 | rawson
# Processing record 33 of set 2 | port augusta
# Processing record 34 of set 2 | canakkale
# Processing record 35 of set 2 | yumen
# Processing record 36 of set 2 | tasiilaq
# Processing record 37 of set 2 | ketchikan
# Processing record 38 of set 2 | bambanglipuro
# Processing record 39 of set 2 | dikson
# Processing record 40 of set 2 | amalapuram
# Processing record 41 of set 2 | ballina
# Processing record 42 of set 2 | adwa
# Processing record 43 of set 2 | east london
# Processing record 44 of set 2 | karatau
# Processing record 45 of set 2 | grand gaube
# Processing record 46 of set 2 | guerrero negro
# Processing record 47 of set 2 | alekseyevsk
# Processing record 48 of set 2 | varhaug
# Processing record 49 of set 2 | bluff
# Processing record 50 of set 2 | umzimvubu
# City not found. Skipping umzimvubu
# Processing record 1 of set 3 | kavieng
# Processing record 2 of set 3 | baytown
# Processing record 3 of set 3 | guaranda
# Processing record 4 of set 3 | kamenka
# Processing record 5 of set 3 | kayerkan
# Processing record 6 of set 3 | arraial do cabo
# Processing record 7 of set 3 | lavrentiya
# Processing record 8 of set 3 | dunedin
# Processing record 9 of set 3 | shihezi
# Processing record 10 of set 3 | tumannyy
# City not found. Skipping tumannyy
# Processing record 11 of set 3 | ponta do sol
# Processing record 12 of set 3 | baykit
# Processing record 13 of set 3 | bonavista
# Processing record 14 of set 3 | praia
# Processing record 15 of set 3 | houston
# Processing record 16 of set 3 | korem
# Processing record 17 of set 3 | toshkivka
# Processing record 18 of set 3 | nikolskoye
# Processing record 19 of set 3 | tuktoyaktuk
# Processing record 20 of set 3 | severo-kurilsk
# Processing record 21 of set 3 | inirida
# Processing record 22 of set 3 | leshukonskoye
# Processing record 23 of set 3 | kapaa
# Processing record 24 of set 3 | saint-pierre
# Processing record 25 of set 3 | kruisfontein
# Processing record 26 of set 3 | wasilla
# Processing record 27 of set 3 | pedasi
# Processing record 28 of set 3 | benalla
# Processing record 29 of set 3 | kununurra
# Processing record 30 of set 3 | cidreira
# Processing record 31 of set 3 | tilichiki
# Processing record 32 of set 3 | muravlenko
# Processing record 33 of set 3 | bath
# Processing record 34 of set 3 | tezu
# Processing record 35 of set 3 | lamar
# Processing record 36 of set 3 | acapulco
# Processing record 37 of set 3 | new norfolk
# Processing record 38 of set 3 | areka
# Processing record 39 of set 3 | waipawa
# Processing record 40 of set 3 | haibowan
# City not found. Skipping haibowan
# Processing record 41 of set 3 | englewood
# Processing record 42 of set 3 | alofi
# Processing record 43 of set 3 | hithadhoo
# Processing record 44 of set 3 | manggar
# Processing record 45 of set 3 | provideniya
# Processing record 46 of set 3 | la cruz
# Processing record 47 of set 3 | saskylakh
# Processing record 48 of set 3 | bethel
# Processing record 49 of set 3 | samoded
# Processing record 50 of set 3 | karamea
# City not found. Skipping karamea
# Processing record 1 of set 4 | trapani
# Processing record 2 of set 4 | port hedland
# Processing record 3 of set 4 | rundu
# Processing record 4 of set 4 | attawapiskat
# City not found. Skipping attawapiskat
# Processing record 5 of set 4 | maniitsoq
# Processing record 6 of set 4 | hilo
# Processing record 7 of set 4 | sentyabrskiy
# City not found. Skipping sentyabrskiy
# Processing record 8 of set 4 | veinticinco de mayo
# Processing record 9 of set 4 | rath
# Processing record 10 of set 4 | saleaula
# City not found. Skipping saleaula
# Processing record 11 of set 4 | kaeo
# Processing record 12 of set 4 | sitka
# Processing record 13 of set 4 | ijaki
# City not found. Skipping ijaki
# Processing record 14 of set 4 | khiv
# Processing record 15 of set 4 | sept-iles
# Processing record 16 of set 4 | leningradskiy
# Processing record 17 of set 4 | hofn
# Processing record 18 of set 4 | busselton
# Processing record 19 of set 4 | fairview
# Processing record 20 of set 4 | peterhead
# Processing record 21 of set 4 | flora
# Processing record 22 of set 4 | jalu
# Processing record 23 of set 4 | newport
# Processing record 24 of set 4 | okandja
# City not found. Skipping okandja
# Processing record 25 of set 4 | urdoma
# Processing record 26 of set 4 | camacha
# Processing record 27 of set 4 | brownsville
# Processing record 28 of set 4 | yar-sale
# Processing record 29 of set 4 | belushya guba
# City not found. Skipping belushya guba
# Processing record 30 of set 4 | caracollo
# Processing record 31 of set 4 | nizhniy kuranakh
# Processing record 32 of set 4 | nurota
# Processing record 33 of set 4 | kampene
# Processing record 34 of set 4 | clyde river
# Processing record 35 of set 4 | fairbanks
# Processing record 36 of set 4 | yenagoa
# Processing record 37 of set 4 | thunder bay
# Processing record 38 of set 4 | birjand
# Processing record 39 of set 4 | avera
# Processing record 40 of set 4 | arsk
# Processing record 41 of set 4 | lahat
# Processing record 42 of set 4 | srednekolymsk
# Processing record 43 of set 4 | san patricio
# Processing record 44 of set 4 | preobrazheniye
# Processing record 45 of set 4 | saldanha
# Processing record 46 of set 4 | hualmay
# Processing record 47 of set 4 | richards bay
# Processing record 48 of set 4 | nongan
# Processing record 49 of set 4 | vila franca do campo
# Processing record 50 of set 4 | tuatapere
# Processing record 1 of set 5 | haines junction
# Processing record 2 of set 5 | marcona
# City not found. Skipping marcona
# Processing record 3 of set 5 | klaksvik
# Processing record 4 of set 5 | hunza
# City not found. Skipping hunza
# Processing record 5 of set 5 | opuwo
# Processing record 6 of set 5 | gat
# Processing record 7 of set 5 | chitral
# Processing record 8 of set 5 | kamogawa
# Processing record 9 of set 5 | chagda
# City not found. Skipping chagda
# Processing record 10 of set 5 | bathsheba
# Processing record 11 of set 5 | aksarka
# Processing record 12 of set 5 | valdivia
# Processing record 13 of set 5 | karaul
# City not found. Skipping karaul
# Processing record 14 of set 5 | aklavik
# Processing record 15 of set 5 | kloulklubed
# Processing record 16 of set 5 | skegness
# Processing record 17 of set 5 | svetlogorsk
# Processing record 18 of set 5 | jumla
# Processing record 19 of set 5 | honiara
# Processing record 20 of set 5 | la paz
# Processing record 21 of set 5 | coahuayana
# Processing record 22 of set 5 | lewiston
# Processing record 23 of set 5 | gorontalo
# Processing record 24 of set 5 | sechura
# Processing record 25 of set 5 | lagoa
# Processing record 26 of set 5 | oyama
# Processing record 27 of set 5 | garden city
# Processing record 28 of set 5 | qianan
# Processing record 29 of set 5 | lazaro cardenas
# Processing record 30 of set 5 | shiraz
# Processing record 31 of set 5 | portland
# Processing record 32 of set 5 | coulihaut
# City not found. Skipping coulihaut
# Processing record 33 of set 5 | chara
# Processing record 34 of set 5 | haukipudas
# Processing record 35 of set 5 | coihaique
# Processing record 36 of set 5 | ngukurr
# City not found. Skipping ngukurr
# Processing record 37 of set 5 | taree
# Processing record 38 of set 5 | vila velha
# Processing record 39 of set 5 | sulangan
# Processing record 40 of set 5 | lodja
# Processing record 41 of set 5 | asaba
# Processing record 42 of set 5 | dondo
# Processing record 43 of set 5 | kodiak
# Processing record 44 of set 5 | aguimes
# Processing record 45 of set 5 | moindou
# Processing record 46 of set 5 | hollola
# Processing record 47 of set 5 | narsaq
# Processing record 48 of set 5 | waddan
# Processing record 49 of set 5 | north bend
# Processing record 50 of set 5 | urumqi
# Processing record 1 of set 6 | vernon
# Processing record 2 of set 6 | nome
# Processing record 3 of set 6 | khatanga
# Processing record 4 of set 6 | karratha
# Processing record 5 of set 6 | westport
# Processing record 6 of set 6 | yichang
# Processing record 7 of set 6 | muros
# Processing record 8 of set 6 | longyearbyen
# Processing record 9 of set 6 | kieta
# Processing record 10 of set 6 | davila
# Processing record 11 of set 6 | komsomolskiy
# Processing record 12 of set 6 | poum
# Processing record 13 of set 6 | beloha
# Processing record 14 of set 6 | myitkyina
# Processing record 15 of set 6 | roma
# Processing record 16 of set 6 | goundam
# Processing record 17 of set 6 | road town
# Processing record 18 of set 6 | matara
# Processing record 19 of set 6 | cradock
# Processing record 20 of set 6 | khandyga
# Processing record 21 of set 6 | tallahassee
# Processing record 22 of set 6 | lasa
# Processing record 23 of set 6 | cap malheureux
# Processing record 24 of set 6 | namibe
# Processing record 25 of set 6 | margate
# Processing record 26 of set 6 | ondangwa
# Processing record 27 of set 6 | hokitika
# Processing record 28 of set 6 | hobyo
# Processing record 29 of set 6 | bali chak
# Processing record 30 of set 6 | constitucion
# Processing record 31 of set 6 | esperance
# Processing record 32 of set 6 | amderma
# City not found. Skipping amderma
# Processing record 33 of set 6 | saint anthony
# Processing record 34 of set 6 | biak
# Processing record 35 of set 6 | isangel
# Processing record 36 of set 6 | mahebourg
# Processing record 37 of set 6 | rocha
# Processing record 38 of set 6 | san cristobal
# Processing record 39 of set 6 | riyadh
# Processing record 40 of set 6 | cadca
# Processing record 41 of set 6 | solovetskiy
# City not found. Skipping solovetskiy
# Processing record 42 of set 6 | lorengau
# Processing record 43 of set 6 | belmonte
# Processing record 44 of set 6 | naze
# Processing record 45 of set 6 | pevek
# Processing record 46 of set 6 | katsuura
# Processing record 47 of set 6 | erice
# Processing record 48 of set 6 | hurricane
# Processing record 49 of set 6 | greenwood
# Processing record 50 of set 6 | puerto madero
# Processing record 1 of set 7 | vaasa
# Processing record 2 of set 7 | burns lake
# Processing record 3 of set 7 | ha giang
# Processing record 4 of set 7 | tommot
# Processing record 5 of set 7 | nizhneyansk
# City not found. Skipping nizhneyansk
# Processing record 6 of set 7 | sorland
# Processing record 7 of set 7 | georgetown
# Processing record 8 of set 7 | shache
# Processing record 9 of set 7 | mango
# Processing record 10 of set 7 | talcahuano
# Processing record 11 of set 7 | venado
# Processing record 12 of set 7 | lima
# Processing record 13 of set 7 | wanning
# Processing record 14 of set 7 | newport beach
# Processing record 15 of set 7 | el tigre
# Processing record 16 of set 7 | songadh
# Processing record 17 of set 7 | rio gallegos
# Processing record 18 of set 7 | souillac
# Processing record 19 of set 7 | pamanukan
# Processing record 20 of set 7 | humberto de campos
# Processing record 21 of set 7 | barentsburg
# City not found. Skipping barentsburg
# Processing record 22 of set 7 | ribeira grande
# Processing record 23 of set 7 | eldikan
# City not found. Skipping eldikan
# Processing record 24 of set 7 | necochea
# Processing record 25 of set 7 | dingle
# Processing record 26 of set 7 | northam
# Processing record 27 of set 7 | wagar
# Processing record 28 of set 7 | mae hong son
# Processing record 29 of set 7 | pisco
# Processing record 30 of set 7 | ust-uda
# Processing record 31 of set 7 | ola
# Processing record 32 of set 7 | pangai
# Processing record 33 of set 7 | sao miguel do araguaia
# Processing record 34 of set 7 | maragogi
# Processing record 35 of set 7 | vicuna
# Processing record 36 of set 7 | denpasar
# Processing record 37 of set 7 | pozo colorado
# Processing record 38 of set 7 | asau
# Processing record 39 of set 7 | faanui
# Processing record 40 of set 7 | adrar
# Processing record 41 of set 7 | kerema
# Processing record 42 of set 7 | iracoubo
# Processing record 43 of set 7 | balkanabat
# Processing record 44 of set 7 | brae
# Processing record 45 of set 7 | jiehu
# Processing record 46 of set 7 | rio grande
# Processing record 47 of set 7 | makarska
# Processing record 48 of set 7 | boyolangu
# Processing record 49 of set 7 | chuy
# Processing record 50 of set 7 | la ronge
# Processing record 1 of set 8 | aykhal
# Processing record 2 of set 8 | verkhnyaya inta
# Processing record 3 of set 8 | beringovskiy
# Processing record 4 of set 8 | matagami
# Processing record 5 of set 8 | saint george
# Processing record 6 of set 8 | sabzevar
# Processing record 7 of set 8 | verkhnevilyuysk
# Processing record 8 of set 8 | paamiut
# Processing record 9 of set 8 | el carmen
# Processing record 10 of set 8 | okhotsk
# Processing record 11 of set 8 | husavik
# Processing record 12 of set 8 | leh
# Processing record 13 of set 8 | nantucket
# Processing record 14 of set 8 | molteno
# Processing record 15 of set 8 | pemba
# Processing record 16 of set 8 | salalah
# Processing record 17 of set 8 | broome
# Processing record 18 of set 8 | wisconsin rapids
# Processing record 19 of set 8 | pitimbu
# Processing record 20 of set 8 | qinhuangdao
# Processing record 21 of set 8 | saint-philippe
# Processing record 22 of set 8 | olafsvik
# Processing record 23 of set 8 | hervey bay
# Processing record 24 of set 8 | tahoua
# Processing record 25 of set 8 | bagdarin
# Processing record 26 of set 8 | ordynskoye
# Processing record 27 of set 8 | tura
# Processing record 28 of set 8 | lang son
# Processing record 29 of set 8 | huanren
# Processing record 30 of set 8 | clinton
# Processing record 31 of set 8 | pringsewu
# Processing record 32 of set 8 | vanimo
# Processing record 33 of set 8 | torbay
# Processing record 34 of set 8 | parasia
# Processing record 35 of set 8 | vardo
# Processing record 36 of set 8 | mookane
# Processing record 37 of set 8 | pierre
# Processing record 38 of set 8 | jibuti
# Processing record 39 of set 8 | miyako
# Processing record 40 of set 8 | karkaralinsk
# City not found. Skipping karkaralinsk
# Processing record 41 of set 8 | yuci
# Processing record 42 of set 8 | hami
# Processing record 43 of set 8 | januaria
# Processing record 44 of set 8 | liverpool
# Processing record 45 of set 8 | darlington
# Processing record 46 of set 8 | eureka
# Processing record 47 of set 8 | blairmore
# Processing record 48 of set 8 | alice springs
# Processing record 49 of set 8 | ostrovnoy
# Processing record 50 of set 8 | praya
# Processing record 1 of set 9 | soure
# Processing record 2 of set 9 | pimentel
# Processing record 3 of set 9 | nuuk
# Processing record 4 of set 9 | carballo
# Processing record 5 of set 9 | bud
# Processing record 6 of set 9 | revelstoke
# Processing record 7 of set 9 | terney
# Processing record 8 of set 9 | simbahan
# Processing record 9 of set 9 | namatanai
# Processing record 10 of set 9 | yialos
# City not found. Skipping yialos
# Processing record 11 of set 9 | laguna
# Processing record 12 of set 9 | mildura
# Processing record 13 of set 9 | mandan
# Processing record 14 of set 9 | sangar
# Processing record 15 of set 9 | ko samui
# Processing record 16 of set 9 | geraldton
# Processing record 17 of set 9 | sheridan
# Processing record 18 of set 9 | yambio
# Processing record 19 of set 9 | norman wells
# Processing record 20 of set 9 | aksu
# Processing record 21 of set 9 | tigil
# Processing record 22 of set 9 | bubaque
# Processing record 23 of set 9 | carutapera
# Processing record 24 of set 9 | shush
# Processing record 25 of set 9 | luderitz
# Processing record 26 of set 9 | broken hill
# Processing record 27 of set 9 | marsh harbour
# Processing record 28 of set 9 | cockburn town
# Processing record 29 of set 9 | sisimiut
# Processing record 30 of set 9 | birao
# Processing record 31 of set 9 | malpe
# Processing record 32 of set 9 | bedesa
# Processing record 33 of set 9 | buraydah
# Processing record 34 of set 9 | van
# Processing record 35 of set 9 | kajaani
# Processing record 36 of set 9 | burica
# City not found. Skipping burica
# Processing record 37 of set 9 | canavieiras
# Processing record 38 of set 9 | chumikan
# Processing record 39 of set 9 | poso
# Processing record 40 of set 9 | sydney
# Processing record 41 of set 9 | lata
# Processing record 42 of set 9 | liwale
# Processing record 43 of set 9 | bambous virieux
# Processing record 44 of set 9 | acurenam
# Processing record 45 of set 9 | umm kaddadah
# Processing record 46 of set 9 | bom jesus
# Processing record 47 of set 9 | rudnogorsk
# Processing record 48 of set 9 | udachnyy
# Processing record 49 of set 9 | uyuni
# Processing record 50 of set 9 | kijang
# Processing record 1 of set 10 | andreyevo
# Processing record 2 of set 10 | manado
# Processing record 3 of set 10 | dioknisi
# Processing record 4 of set 10 | bengkulu
# Processing record 5 of set 10 | awjilah
# Processing record 6 of set 10 | mutsamudu
# City not found. Skipping mutsamudu
# Processing record 7 of set 10 | duz
# City not found. Skipping duz
# Processing record 8 of set 10 | barbar
# City not found. Skipping barbar
# Processing record 9 of set 10 | strijen
# Processing record 10 of set 10 | hasaki
# Processing record 11 of set 10 | isabela
# Processing record 12 of set 10 | hamilton
# Processing record 13 of set 10 | taltal
# Processing record 14 of set 10 | empangeni
# Processing record 15 of set 10 | cordoba
# Processing record 16 of set 10 | bandrele
# Processing record 17 of set 10 | offenburg
# Processing record 18 of set 10 | baiyin
# Processing record 19 of set 10 | merauke
# Processing record 20 of set 10 | cartagena
# Processing record 21 of set 10 | anolaima
# Processing record 22 of set 10 | kristianstad
# Processing record 23 of set 10 | autazes
# Processing record 24 of set 10 | pital
# Processing record 25 of set 10 | te anau
# Processing record 26 of set 10 | mariental
# Processing record 27 of set 10 | vao
# Processing record 28 of set 10 | ranot
# Processing record 29 of set 10 | orocue
# Processing record 30 of set 10 | hanzhong
# Processing record 31 of set 10 | tunduru
# City not found. Skipping tunduru
# Processing record 32 of set 10 | inhambane
# Processing record 33 of set 10 | ucluelet
# Processing record 34 of set 10 | kamenskoye
# City not found. Skipping kamenskoye
# Processing record 35 of set 10 | west bay
# Processing record 36 of set 10 | inta
# Processing record 37 of set 10 | hammerfest
# Processing record 38 of set 10 | mumbwa
# Processing record 39 of set 10 | chokurdakh
# Processing record 40 of set 10 | xuddur
# Processing record 41 of set 10 | xingtai
# Processing record 42 of set 10 | kidal
# Processing record 43 of set 10 | teya
# Processing record 44 of set 10 | krasnaya gorbatka
# Processing record 45 of set 10 | elk city
# Processing record 46 of set 10 | nizhniye achaluki
# Processing record 47 of set 10 | camargo
# Processing record 48 of set 10 | shelbyville
# Processing record 49 of set 10 | loreto
# Processing record 50 of set 10 | rajapur
# Processing record 1 of set 11 | pochutla
# Processing record 2 of set 11 | huejucar
# Processing record 3 of set 11 | gorele
# Processing record 4 of set 11 | vilyuysk
# Processing record 5 of set 11 | barreirinhas
# Processing record 6 of set 11 | kisanga
# Processing record 7 of set 11 | seydi
# Processing record 8 of set 11 | nehe
# Processing record 9 of set 11 | borovoy
# Processing record 10 of set 11 | megion
# Processing record 11 of set 11 | mys shmidta
# City not found. Skipping mys shmidta
# Processing record 12 of set 11 | los llanos de aridane
# Processing record 13 of set 11 | torbat-e jam
# Processing record 14 of set 11 | uyskoye
# Processing record 15 of set 11 | ilulissat
# Processing record 16 of set 11 | vysokogornyy
# Processing record 17 of set 11 | marv dasht
# City not found. Skipping marv dasht
# Processing record 18 of set 11 | rumuruti
# Processing record 19 of set 11 | mahibadhoo
# Processing record 20 of set 11 | nelson bay
# Processing record 21 of set 11 | malwan
# City not found. Skipping malwan
# Processing record 22 of set 11 | turukhansk
# Processing record 23 of set 11 | maracana
# Processing record 24 of set 11 | kharp
# Processing record 25 of set 11 | port maria
# Processing record 26 of set 11 | lisala
# Processing record 27 of set 11 | goderich
# Processing record 28 of set 11 | mecca
# Processing record 29 of set 11 | marienburg
# Processing record 30 of set 11 | tubmanburg
# Processing record 31 of set 11 | anaconda
# Processing record 32 of set 11 | russkaya polyana
# Processing record 33 of set 11 | kismayo
# Processing record 34 of set 11 | saint-leu
# Processing record 35 of set 11 | trairi
# Processing record 36 of set 11 | port hardy
# Processing record 37 of set 11 | hartselle
# Processing record 38 of set 11 | vagur
# Processing record 39 of set 11 | tanggu
# Processing record 40 of set 11 | shaowu
# Processing record 41 of set 11 | ornskoldsvik
# Processing record 42 of set 11 | buon me thuot
# City not found. Skipping buon me thuot
# Processing record 43 of set 11 | ulaangom
# Processing record 44 of set 11 | sorvag
# City not found. Skipping sorvag
# Processing record 45 of set 11 | mindelo
# Processing record 46 of set 11 | wanaka
# Processing record 47 of set 11 | illela
# Processing record 48 of set 11 | gawler
# Processing record 49 of set 11 | porto novo
# Processing record 50 of set 11 | kaoma
# Processing record 1 of set 12 | quetta
# Processing record 2 of set 12 | fagersta
# Processing record 3 of set 12 | craciunelu de jos
# Processing record 4 of set 12 | ostrovskoye
# Processing record 5 of set 12 | lukulu
# Processing record 6 of set 12 | pala
# Processing record 7 of set 12 | abu zabad
# Processing record 8 of set 12 | takoradi
# Processing record 9 of set 12 | ilorin
# Processing record 10 of set 12 | balabac
# Processing record 11 of set 12 | quang ngai
# Processing record 12 of set 12 | lolua
# City not found. Skipping lolua
# Processing record 13 of set 12 | golden gate
# Processing record 14 of set 12 | tinyahuarco
# Processing record 15 of set 12 | chifeng
# Processing record 16 of set 12 | aktash
# Processing record 17 of set 12 | bay roberts
# Processing record 18 of set 12 | chicama
# Processing record 19 of set 12 | vodnyy
# Processing record 20 of set 12 | visakhapatnam
# Processing record 21 of set 12 | cap-aux-meules
# Processing record 22 of set 12 | kedrovyy
# Processing record 23 of set 12 | half moon bay
# Processing record 24 of set 12 | cabedelo
# Processing record 25 of set 12 | arman
# Processing record 26 of set 12 | strezhevoy
# Processing record 27 of set 12 | dujuma
# City not found. Skipping dujuma
# Processing record 28 of set 12 | kassala
# Processing record 29 of set 12 | santa cruz
# Processing record 30 of set 12 | sandakan
# Processing record 31 of set 12 | taman
# Processing record 32 of set 12 | labuan
# Processing record 33 of set 12 | paradwip
# City not found. Skipping paradwip
# Processing record 34 of set 12 | reconquista
# Processing record 35 of set 12 | codrington
# Processing record 36 of set 12 | banda aceh
# Processing record 37 of set 12 | padang
# Processing record 38 of set 12 | shingu
# Processing record 39 of set 12 | kasongo-lunda
# Processing record 40 of set 12 | ossora
# Processing record 41 of set 12 | palabuhanratu
# City not found. Skipping palabuhanratu
# Processing record 42 of set 12 | redmond
# Processing record 43 of set 12 | srivardhan
# Processing record 44 of set 12 | luanda
# ---------------------------
# Data retrieval complete
# ---------------------------

# %%
len(city_data)
# Out:
# 546

# %%
city_data[-1]
# Out:
# {'City': 'luanda',
#  'Lat': -8.8368,
#  'Lng': 13.2343,
#  'Max Temp': 69.8,
#  'Humidity': 94,
#  'Cloudiness': 75,
#  'Wind Speed': 2.3,
#  'Country': 'AO',
#  'Date': '2021-09-13 05:23:30'}

# %%
# convert list to DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     grindavik  63.8424  -22.4338     55.35       100          90
# 1          bhag  29.0415   67.8239     96.85        38           2
# 2        atuona  -9.8000 -139.0333     78.12        70           0
# 3  novomyrhorod  48.7811   31.6420     64.08        58          45
# 4         vaini -21.2000 -175.2000     77.16        88          40
# 5   yellowknife  62.4560 -114.3525     48.72       100          90
# 6        hobart -42.8794  147.3294     52.05        68          40
# 7       ponnani  10.7670   75.9252     78.12        86         100
# 8         kaili  -3.4626  120.2147     75.69        74          96
# 9           eyl   7.9803   49.8164     82.40        57          44
#
#    Wind Speed Country                 Date
# 0       28.77      IS  2021-09-13 05:23:20
# 1        7.96      PK  2021-09-13 05:23:21
# 2       20.87      PF  2021-09-13 05:23:21
# 3        4.94      UA  2021-09-13 05:23:21
# 4        6.91      TO  2021-09-13 05:23:22
# 5        3.44      CA  2021-09-13 05:23:22
# 6        1.99      AU  2021-09-13 05:19:22
# 7        7.70      IN  2021-09-13 05:23:22
# 8        3.36      ID  2021-09-13 05:23:23
# 9       28.43      SO  2021-09-13 05:23:23

# %%
city_data_df.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0     grindavik      IS  2021-09-13 05:23:20  63.8424  -22.4338     55.35
# 1          bhag      PK  2021-09-13 05:23:21  29.0415   67.8239     96.85
# 2        atuona      PF  2021-09-13 05:23:21  -9.8000 -139.0333     78.12
# 3  novomyrhorod      UA  2021-09-13 05:23:21  48.7811   31.6420     64.08
# 4         vaini      TO  2021-09-13 05:23:22 -21.2000 -175.2000     77.16
# 5   yellowknife      CA  2021-09-13 05:23:22  62.4560 -114.3525     48.72
# 6        hobart      AU  2021-09-13 05:19:22 -42.8794  147.3294     52.05
# 7       ponnani      IN  2021-09-13 05:23:22  10.7670   75.9252     78.12
# 8         kaili      ID  2021-09-13 05:23:23  -3.4626  120.2147     75.69
# 9           eyl      SO  2021-09-13 05:23:23   7.9803   49.8164     82.40
#
#    Humidity  Cloudiness  Wind Speed
# 0       100          90       28.77
# 1        38           2        7.96
# 2        70           0       20.87
# 3        58          45        4.94
# 4        88          40        6.91
# 5       100          90        3.44
# 6        68          40        1.99
# 7        86         100        7.70
# 8        74          96        3.36
# 9        57          44       28.43

# %%
# create the output file (csv)
output_data_file = 'weather_data/cities.csv'
# export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label='City_ID')

# %%
# extract relevant fields from the dataframe for plotting.
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
# import the time module
import time
# get today's date in seconds
today = time.time()
print(datetime.utcfromtimestamp(today).strftime('%x'))

today = time.strftime('%x')

fig, ax = plt.subplots(figsize=(7,5))
ax.scatter(lats, 
           max_temps, 
           marker='o',
           facecolors='b', 
           edgecolors='k', 
           linewidth=1,
           alpha=0.3,
           label='Cities')
ax.set_xlabel('Latitude')
ax.set_ylabel('Max Temperature (F)')
ax.set_title('City Latitude vs. Max Temperature  ' + today)
ax.grid()
plt.savefig('weather_data/fig1.png')
plt.show()
# Out:
# 09/13/21

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax.scatter(lats, 
           humidity, 
           marker='o',
           facecolors='b', 
           edgecolors='k', 
           linewidth=1,
           alpha=0.5,
           label='Cities')
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.set_title('City Latitude vs. Humidity (%)  ' + today)
ax.grid()
plt.savefig('weather_data/fig2.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax.scatter(lats, 
           cloudiness, 
           marker='o',
           facecolors='b', 
           edgecolors='k', 
           linewidth=1,
           alpha=0.5,
           label='Cities')
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness (%)')
ax.set_title('City Latitude vs. Cloudiness (%)  ' + today)
ax.grid()
plt.savefig('weather_data/fig3.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax.scatter(lats, 
           wind_speed, 
           marker='o',
           facecolors='b', 
           edgecolors='k', 
           linewidth=1,
           alpha=0.5,
           label='Cities')
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed (mph)')
ax.set_title('City Latitude vs. Wind Speed (mph)  ' + today)
ax.grid()
plt.savefig('weather_data/fig4.png')
plt.show()
