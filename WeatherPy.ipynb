# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=1500)
lngs = np.random.uniform(-180,180,size=1500)
lat_lngs = zip(lats,lngs)
coordinates = list(lat_lngs)   # unpack. zipped tuple is removed once unpacked.

# %%
from citipy import citipy
for coordinate in coordinates:
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name, 
    #     citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
    pass

# %%
# create a list to hold cities
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # if the found city is unique, then we add it to the cities list
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 585

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
# import the datetime module
from datetime import datetime

# import the requests library
import requests

# import the API key
from config import weather_api_key

# starting URL for Weather Map API call.
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=' + weather_api_key

# %%
# create an empty list to hold the weather data
city_data = []
# print the beginning of the logging.
print('Beginning Data Retrieval    ')
print('----------------------------')

# create counters
record_count = 1
set_count = 1

# loop through all the cities in out list
for i, city in enumerate(cities):

    # group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        record_count = 1
        set_count += 1
    # create endpoint URL with each city
    city_url = url + '&q=' + city.replace(' ', '+')
    # log the URL, record and set numbers and the city
    print(f'Processing record {record_count} of set {set_count} | {city}')
    # add 1 to record_count
    record_count += 1

    # try-except
    try:
        # parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        #city_name = city_weather['name']
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds= city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        # convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # append info into the city_data list
        city_data.append({'City': city,
                          'Lat': city_lat, 
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Date': city_date})
    except:
        print('City not found. Skipping ' + city)
        pass

# indicate that data loading is complete.
print('---------------------------')
print('Data retrieval complete    ')
print('---------------------------')
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing record 1 of set 1 | port hawkesbury
# Processing record 2 of set 1 | kapaa
# Processing record 3 of set 1 | taolanaro
# City not found. Skipping taolanaro
# Processing record 4 of set 1 | lata
# Processing record 5 of set 1 | hithadhoo
# Processing record 6 of set 1 | busselton
# Processing record 7 of set 1 | ilulissat
# Processing record 8 of set 1 | san pedro
# Processing record 9 of set 1 | ushuaia
# Processing record 10 of set 1 | port alfred
# Processing record 11 of set 1 | sao filipe
# Processing record 12 of set 1 | seoul
# Processing record 13 of set 1 | pevek
# Processing record 14 of set 1 | albany
# Processing record 15 of set 1 | sinnamary
# Processing record 16 of set 1 | saskylakh
# Processing record 17 of set 1 | cape town
# Processing record 18 of set 1 | bethel
# Processing record 19 of set 1 | khatanga
# Processing record 20 of set 1 | vaini
# Processing record 21 of set 1 | hermanus
# Processing record 22 of set 1 | salalah
# Processing record 23 of set 1 | vaitupu
# City not found. Skipping vaitupu
# Processing record 24 of set 1 | hobart
# Processing record 25 of set 1 | krasnoselkup
# Processing record 26 of set 1 | rikitea
# Processing record 27 of set 1 | lakshmipur
# Processing record 28 of set 1 | atuona
# Processing record 29 of set 1 | mataura
# Processing record 30 of set 1 | east wenatchee bench
# Processing record 31 of set 1 | mar del plata
# Processing record 32 of set 1 | barentsburg
# City not found. Skipping barentsburg
# Processing record 33 of set 1 | ahuimanu
# Processing record 34 of set 1 | gornopravdinsk
# Processing record 35 of set 1 | bredasdorp
# Processing record 36 of set 1 | juneau
# Processing record 37 of set 1 | taoudenni
# Processing record 38 of set 1 | nikolskoye
# Processing record 39 of set 1 | bridgetown
# Processing record 40 of set 1 | georgetown
# Processing record 41 of set 1 | illoqqortoormiut
# City not found. Skipping illoqqortoormiut
# Processing record 42 of set 1 | bambous virieux
# Processing record 43 of set 1 | mehamn
# Processing record 44 of set 1 | yellowknife
# Processing record 45 of set 1 | mubi
# Processing record 46 of set 1 | jarjis
# City not found. Skipping jarjis
# Processing record 47 of set 1 | yerbogachen
# Processing record 48 of set 1 | punta arenas
# Processing record 49 of set 1 | namibe
# Processing record 50 of set 1 | dingle
# Processing record 1 of set 2 | bengkulu
# Processing record 2 of set 2 | tasiilaq
# Processing record 3 of set 2 | ardakan
# Processing record 4 of set 2 | haines junction
# Processing record 5 of set 2 | constitucion
# Processing record 6 of set 2 | upernavik
# Processing record 7 of set 2 | provideniya
# Processing record 8 of set 2 | myaundzha
# Processing record 9 of set 2 | saint anthony
# Processing record 10 of set 2 | la ronge
# Processing record 11 of set 2 | aklavik
# Processing record 12 of set 2 | nanortalik
# Processing record 13 of set 2 | qasigiannguit
# Processing record 14 of set 2 | malwan
# City not found. Skipping malwan
# Processing record 15 of set 2 | mnogovershinnyy
# Processing record 16 of set 2 | puerto ayora
# Processing record 17 of set 2 | qaanaaq
# Processing record 18 of set 2 | tezpur
# Processing record 19 of set 2 | dicabisagan
# Processing record 20 of set 2 | gat
# Processing record 21 of set 2 | maniitsoq
# Processing record 22 of set 2 | carnarvon
# Processing record 23 of set 2 | klaksvik
# Processing record 24 of set 2 | amderma
# City not found. Skipping amderma
# Processing record 25 of set 2 | oussouye
# Processing record 26 of set 2 | castro
# Processing record 27 of set 2 | pucallpa
# Processing record 28 of set 2 | tallahassee
# Processing record 29 of set 2 | belushya guba
# City not found. Skipping belushya guba
# Processing record 30 of set 2 | kaitangata
# Processing record 31 of set 2 | kruisfontein
# Processing record 32 of set 2 | netivot
# Processing record 33 of set 2 | butaritari
# Processing record 34 of set 2 | halalo
# City not found. Skipping halalo
# Processing record 35 of set 2 | hilo
# Processing record 36 of set 2 | jamestown
# Processing record 37 of set 2 | makat
# Processing record 38 of set 2 | saint-joseph
# Processing record 39 of set 2 | scottsbluff
# Processing record 40 of set 2 | tuktoyaktuk
# Processing record 41 of set 2 | lahaina
# Processing record 42 of set 2 | waipawa
# Processing record 43 of set 2 | lebu
# Processing record 44 of set 2 | christchurch
# Processing record 45 of set 2 | cangucu
# Processing record 46 of set 2 | saldanha
# Processing record 47 of set 2 | bougouni
# Processing record 48 of set 2 | porto santo
# Processing record 49 of set 2 | san joaquin
# Processing record 50 of set 2 | havelock
# Processing record 1 of set 3 | play cu
# City not found. Skipping play cu
# Processing record 2 of set 3 | bluff
# Processing record 3 of set 3 | olafsvik
# Processing record 4 of set 3 | vila
# Processing record 5 of set 3 | talnakh
# Processing record 6 of set 3 | mahebourg
# Processing record 7 of set 3 | avarua
# Processing record 8 of set 3 | gaoual
# Processing record 9 of set 3 | tura
# Processing record 10 of set 3 | coahuayana
# Processing record 11 of set 3 | alofi
# Processing record 12 of set 3 | new norfolk
# Processing record 13 of set 3 | victoria
# Processing record 14 of set 3 | paamiut
# Processing record 15 of set 3 | edd
# Processing record 16 of set 3 | kamenskoye
# City not found. Skipping kamenskoye
# Processing record 17 of set 3 | sarkand
# Processing record 18 of set 3 | vestmannaeyjar
# Processing record 19 of set 3 | east london
# Processing record 20 of set 3 | nizhneyansk
# City not found. Skipping nizhneyansk
# Processing record 21 of set 3 | beringovskiy
# Processing record 22 of set 3 | geraldton
# Processing record 23 of set 3 | barrow
# Processing record 24 of set 3 | hualmay
# Processing record 25 of set 3 | praia da vitoria
# Processing record 26 of set 3 | ixtapa
# Processing record 27 of set 3 | muros
# Processing record 28 of set 3 | pangnirtung
# Processing record 29 of set 3 | broome
# Processing record 30 of set 3 | scalloway
# City not found. Skipping scalloway
# Processing record 31 of set 3 | burnie
# Processing record 32 of set 3 | kiama
# Processing record 33 of set 3 | lorengau
# Processing record 34 of set 3 | fortuna
# Processing record 35 of set 3 | aljezur
# Processing record 36 of set 3 | kota kinabalu
# Processing record 37 of set 3 | gorno-chuyskiy
# City not found. Skipping gorno-chuyskiy
# Processing record 38 of set 3 | cartagena del chaira
# Processing record 39 of set 3 | asyut
# Processing record 40 of set 3 | gumushane
# City not found. Skipping gumushane
# Processing record 41 of set 3 | bose
# Processing record 42 of set 3 | bohodukhiv
# Processing record 43 of set 3 | caravelas
# Processing record 44 of set 3 | ambulu
# Processing record 45 of set 3 | erenhot
# Processing record 46 of set 3 | saint george
# Processing record 47 of set 3 | kodiak
# Processing record 48 of set 3 | hasaki
# Processing record 49 of set 3 | belaya gora
# Processing record 50 of set 3 | sovetskaya gavan
# Processing record 1 of set 4 | srandakan
# Processing record 2 of set 4 | sawakin
# Processing record 3 of set 4 | los llanos de aridane
# Processing record 4 of set 4 | sentyabrskiy
# City not found. Skipping sentyabrskiy
# Processing record 5 of set 4 | manavalakurichi
# Processing record 6 of set 4 | hamina
# Processing record 7 of set 4 | leh
# Processing record 8 of set 4 | chumphon
# Processing record 9 of set 4 | cape canaveral
# Processing record 10 of set 4 | longyearbyen
# Processing record 11 of set 4 | luderitz
# Processing record 12 of set 4 | portland
# Processing record 13 of set 4 | narsaq
# Processing record 14 of set 4 | sao joao da barra
# Processing record 15 of set 4 | waterloo
# Processing record 16 of set 4 | cockburn town
# Processing record 17 of set 4 | tres arroyos
# Processing record 18 of set 4 | katsuura
# Processing record 19 of set 4 | caconda
# Processing record 20 of set 4 | berdigestyakh
# Processing record 21 of set 4 | mount isa
# Processing record 22 of set 4 | samusu
# City not found. Skipping samusu
# Processing record 23 of set 4 | mae hong son
# Processing record 24 of set 4 | wanning
# Processing record 25 of set 4 | brae
# Processing record 26 of set 4 | grand river south east
# City not found. Skipping grand river south east
# Processing record 27 of set 4 | rafai
# Processing record 28 of set 4 | kavieng
# Processing record 29 of set 4 | severo-yeniseyskiy
# Processing record 30 of set 4 | burayevo
# Processing record 31 of set 4 | bulgan
# Processing record 32 of set 4 | kjopsvik
# Processing record 33 of set 4 | coquimbo
# Processing record 34 of set 4 | hambantota
# Processing record 35 of set 4 | tiebissou
# Processing record 36 of set 4 | longlac
# City not found. Skipping longlac
# Processing record 37 of set 4 | manturovo
# Processing record 38 of set 4 | tabiauea
# City not found. Skipping tabiauea
# Processing record 39 of set 4 | hokitika
# Processing record 40 of set 4 | zhezkazgan
# Processing record 41 of set 4 | mys shmidta
# City not found. Skipping mys shmidta
# Processing record 42 of set 4 | dikson
# Processing record 43 of set 4 | meulaboh
# Processing record 44 of set 4 | mormugao
# Processing record 45 of set 4 | saint-philippe
# Processing record 46 of set 4 | cherskiy
# Processing record 47 of set 4 | solsvik
# City not found. Skipping solsvik
# Processing record 48 of set 4 | attawapiskat
# City not found. Skipping attawapiskat
# Processing record 49 of set 4 | babanusah
# City not found. Skipping babanusah
# Processing record 50 of set 4 | willowmore
# Processing record 1 of set 5 | pangody
# Processing record 2 of set 5 | bubaque
# Processing record 3 of set 5 | ventspils
# Processing record 4 of set 5 | manokwari
# Processing record 5 of set 5 | afgoye
# City not found. Skipping afgoye
# Processing record 6 of set 5 | clyde river
# Processing record 7 of set 5 | praia
# Processing record 8 of set 5 | port elizabeth
# Processing record 9 of set 5 | isangel
# Processing record 10 of set 5 | bonavista
# Processing record 11 of set 5 | sorland
# Processing record 12 of set 5 | chokurdakh
# Processing record 13 of set 5 | arraial do cabo
# Processing record 14 of set 5 | tsihombe
# City not found. Skipping tsihombe
# Processing record 15 of set 5 | tamalameque
# Processing record 16 of set 5 | liyang
# Processing record 17 of set 5 | fukue
# Processing record 18 of set 5 | miyako
# Processing record 19 of set 5 | weyburn
# Processing record 20 of set 5 | faya
# Processing record 21 of set 5 | banda aceh
# Processing record 22 of set 5 | tessalit
# Processing record 23 of set 5 | vsevolodo-vilva
# City not found. Skipping vsevolodo-vilva
# Processing record 24 of set 5 | chicama
# Processing record 25 of set 5 | harper
# Processing record 26 of set 5 | sabana grande de boya
# Processing record 27 of set 5 | great yarmouth
# Processing record 28 of set 5 | baijiantan
# Processing record 29 of set 5 | kuching
# Processing record 30 of set 5 | abapo
# Processing record 31 of set 5 | sorong
# Processing record 32 of set 5 | oktyabrskaya
# City not found. Skipping oktyabrskaya
# Processing record 33 of set 5 | montague
# Processing record 34 of set 5 | marsaxlokk
# Processing record 35 of set 5 | paita
# Processing record 36 of set 5 | porto novo
# Processing record 37 of set 5 | menomonie
# Processing record 38 of set 5 | adrar
# Processing record 39 of set 5 | pavilosta
# Processing record 40 of set 5 | yulara
# Processing record 41 of set 5 | airai
# Processing record 42 of set 5 | dumas
# Processing record 43 of set 5 | viedma
# Processing record 44 of set 5 | broken hill
# Processing record 45 of set 5 | esperance
# Processing record 46 of set 5 | ketchikan
# Processing record 47 of set 5 | taltal
# Processing record 48 of set 5 | lamu
# Processing record 49 of set 5 | nguiu
# City not found. Skipping nguiu
# Processing record 50 of set 5 | pisco
# Processing record 1 of set 6 | darnah
# Processing record 2 of set 6 | pochutla
# Processing record 3 of set 6 | davila
# Processing record 4 of set 6 | karratha
# Processing record 5 of set 6 | hellin
# Processing record 6 of set 6 | brainerd
# Processing record 7 of set 6 | kayerkan
# Processing record 8 of set 6 | mutsamudu
# City not found. Skipping mutsamudu
# Processing record 9 of set 6 | guryevsk
# Processing record 10 of set 6 | itarema
# Processing record 11 of set 6 | sitka
# Processing record 12 of set 6 | cadillac
# Processing record 13 of set 6 | bethanien
# Processing record 14 of set 6 | chuy
# Processing record 15 of set 6 | haikou
# Processing record 16 of set 6 | mandera
# Processing record 17 of set 6 | thompson
# Processing record 18 of set 6 | luena
# Processing record 19 of set 6 | fort saint john
# City not found. Skipping fort saint john
# Processing record 20 of set 6 | viligili
# City not found. Skipping viligili
# Processing record 21 of set 6 | bowen
# Processing record 22 of set 6 | samarai
# Processing record 23 of set 6 | port hardy
# Processing record 24 of set 6 | conceicao do araguaia
# Processing record 25 of set 6 | luanda
# Processing record 26 of set 6 | vostok
# Processing record 27 of set 6 | bargal
# City not found. Skipping bargal
# Processing record 28 of set 6 | ponta do sol
# Processing record 29 of set 6 | evensk
# Processing record 30 of set 6 | chumikan
# Processing record 31 of set 6 | inhambane
# Processing record 32 of set 6 | bathsheba
# Processing record 33 of set 6 | ko samui
# Processing record 34 of set 6 | marinette
# Processing record 35 of set 6 | severo-kurilsk
# Processing record 36 of set 6 | husavik
# Processing record 37 of set 6 | baraya
# Processing record 38 of set 6 | nantucket
# Processing record 39 of set 6 | atasu
# Processing record 40 of set 6 | abha
# Processing record 41 of set 6 | solovetskiy
# City not found. Skipping solovetskiy
# Processing record 42 of set 6 | bankja
# City not found. Skipping bankja
# Processing record 43 of set 6 | fairbanks
# Processing record 44 of set 6 | sola
# Processing record 45 of set 6 | nome
# Processing record 46 of set 6 | mayskiy
# Processing record 47 of set 6 | hammerfest
# Processing record 48 of set 6 | znamenskoye
# Processing record 49 of set 6 | dongsheng
# Processing record 50 of set 6 | montlucon
# Processing record 1 of set 7 | panjab
# Processing record 2 of set 7 | san fernando
# Processing record 3 of set 7 | changying
# Processing record 4 of set 7 | cooma
# Processing record 5 of set 7 | belle fourche
# Processing record 6 of set 7 | golden
# Processing record 7 of set 7 | ponta delgada
# Processing record 8 of set 7 | ingham
# Processing record 9 of set 7 | champerico
# Processing record 10 of set 7 | lewistown
# Processing record 11 of set 7 | sunyani
# Processing record 12 of set 7 | tabou
# Processing record 13 of set 7 | jalu
# Processing record 14 of set 7 | faanui
# Processing record 15 of set 7 | kirakira
# Processing record 16 of set 7 | killybegs
# Processing record 17 of set 7 | kisanga
# Processing record 18 of set 7 | kochevo
# Processing record 19 of set 7 | hargeysa
# Processing record 20 of set 7 | emerald
# Processing record 21 of set 7 | haverfordwest
# Processing record 22 of set 7 | jacksonville
# Processing record 23 of set 7 | prince rupert
# Processing record 24 of set 7 | puro
# Processing record 25 of set 7 | manggar
# Processing record 26 of set 7 | vao
# Processing record 27 of set 7 | duz
# City not found. Skipping duz
# Processing record 28 of set 7 | xingyi
# Processing record 29 of set 7 | kiunga
# Processing record 30 of set 7 | coihaique
# Processing record 31 of set 7 | codrington
# Processing record 32 of set 7 | kampene
# Processing record 33 of set 7 | valdepenas
# Processing record 34 of set 7 | cabo san lucas
# Processing record 35 of set 7 | rasht
# Processing record 36 of set 7 | louis trichardt
# Processing record 37 of set 7 | vardo
# Processing record 38 of set 7 | kamaishi
# Processing record 39 of set 7 | bua yai
# Processing record 40 of set 7 | darwen
# Processing record 41 of set 7 | skalistyy
# City not found. Skipping skalistyy
# Processing record 42 of set 7 | vung tau
# Processing record 43 of set 7 | havre-saint-pierre
# Processing record 44 of set 7 | praya
# Processing record 45 of set 7 | kidodi
# Processing record 46 of set 7 | aitape
# Processing record 47 of set 7 | flinders
# Processing record 48 of set 7 | biltine
# Processing record 49 of set 7 | phuntsholing
# Processing record 50 of set 7 | pathein
# Processing record 1 of set 8 | tarakan
# Processing record 2 of set 8 | torbay
# Processing record 3 of set 8 | ribeira grande
# Processing record 4 of set 8 | palu
# Processing record 5 of set 8 | jurilovca
# Processing record 6 of set 8 | wick
# Processing record 7 of set 8 | hofn
# Processing record 8 of set 8 | iwaki
# Processing record 9 of set 8 | cayenne
# Processing record 10 of set 8 | oranjestad
# Processing record 11 of set 8 | payson
# Processing record 12 of set 8 | namatanai
# Processing record 13 of set 8 | talara
# Processing record 14 of set 8 | hurghada
# Processing record 15 of set 8 | rock sound
# Processing record 16 of set 8 | mitu
# Processing record 17 of set 8 | waitara
# Processing record 18 of set 8 | pemangkat
# Processing record 19 of set 8 | tiksi
# Processing record 20 of set 8 | tashtyp
# Processing record 21 of set 8 | sambava
# Processing record 22 of set 8 | alekseyevka
# Processing record 23 of set 8 | tashla
# Processing record 24 of set 8 | altea
# Processing record 25 of set 8 | russell
# Processing record 26 of set 8 | nanguneri
# Processing record 27 of set 8 | kloulklubed
# Processing record 28 of set 8 | caborca
# Processing record 29 of set 8 | vallenar
# Processing record 30 of set 8 | norman wells
# Processing record 31 of set 8 | havoysund
# Processing record 32 of set 8 | dukat
# Processing record 33 of set 8 | muravlenko
# Processing record 34 of set 8 | leningradskiy
# Processing record 35 of set 8 | galveston
# Processing record 36 of set 8 | marawi
# Processing record 37 of set 8 | sandnessjoen
# Processing record 38 of set 8 | kangaatsiaq
# Processing record 39 of set 8 | kwinana
# Processing record 40 of set 8 | fort nelson
# Processing record 41 of set 8 | alugan
# Processing record 42 of set 8 | conceicao da barra
# Processing record 43 of set 8 | luau
# Processing record 44 of set 8 | kavaratti
# Processing record 45 of set 8 | poronaysk
# Processing record 46 of set 8 | souillac
# Processing record 47 of set 8 | la serena
# Processing record 48 of set 8 | vila velha
# Processing record 49 of set 8 | oleksandrivka
# Processing record 50 of set 8 | vila franca do campo
# Processing record 1 of set 9 | kurmanayevka
# Processing record 2 of set 9 | kahului
# Processing record 3 of set 9 | lardos
# Processing record 4 of set 9 | bereda
# Processing record 5 of set 9 | acarau
# Processing record 6 of set 9 | zhigalovo
# Processing record 7 of set 9 | kysyl-syr
# Processing record 8 of set 9 | alice springs
# Processing record 9 of set 9 | sao felix do xingu
# Processing record 10 of set 9 | artyk
# City not found. Skipping artyk
# Processing record 11 of set 9 | tuatapere
# Processing record 12 of set 9 | saleaula
# City not found. Skipping saleaula
# Processing record 13 of set 9 | rodeo
# Processing record 14 of set 9 | pakxe
# Processing record 15 of set 9 | aksu
# Processing record 16 of set 9 | dedovichi
# Processing record 17 of set 9 | buala
# Processing record 18 of set 9 | urman
# Processing record 19 of set 9 | kabinda
# Processing record 20 of set 9 | solnechnyy
# Processing record 21 of set 9 | sibu
# Processing record 22 of set 9 | cururupu
# Processing record 23 of set 9 | ewa beach
# Processing record 24 of set 9 | laishevo
# Processing record 25 of set 9 | hamilton
# Processing record 26 of set 9 | uray
# Processing record 27 of set 9 | copiapo
# Processing record 28 of set 9 | ituiutaba
# Processing record 29 of set 9 | bilma
# Processing record 30 of set 9 | khonuu
# City not found. Skipping khonuu
# Processing record 31 of set 9 | port blair
# Processing record 32 of set 9 | cascais
# Processing record 33 of set 9 | swan hill
# Processing record 34 of set 9 | rjukan
# Processing record 35 of set 9 | ipil
# Processing record 36 of set 9 | lagoa
# Processing record 37 of set 9 | rio gallegos
# Processing record 38 of set 9 | mocuba
# Processing record 39 of set 9 | toamasina
# Processing record 40 of set 9 | dakar
# Processing record 41 of set 9 | petropavlovsk-kamchatskiy
# Processing record 42 of set 9 | arlit
# Processing record 43 of set 9 | thinadhoo
# Processing record 44 of set 9 | clovis
# Processing record 45 of set 9 | straumen
# Processing record 46 of set 9 | peniche
# Processing record 47 of set 9 | mangan
# Processing record 48 of set 9 | grants
# Processing record 49 of set 9 | letterkenny
# Processing record 50 of set 9 | andevoranto
# City not found. Skipping andevoranto
# Processing record 1 of set 10 | guaimaro
# Processing record 2 of set 10 | tevaitoa
# Processing record 3 of set 10 | ishigaki
# Processing record 4 of set 10 | butembo
# Processing record 5 of set 10 | colon
# Processing record 6 of set 10 | pakpattan
# Processing record 7 of set 10 | hay river
# Processing record 8 of set 10 | yarada
# Processing record 9 of set 10 | cidreira
# Processing record 10 of set 10 | bandarbeyla
# Processing record 11 of set 10 | lumeje
# Processing record 12 of set 10 | venice
# Processing record 13 of set 10 | ekibastuz
# Processing record 14 of set 10 | san patricio
# Processing record 15 of set 10 | louisbourg
# City not found. Skipping louisbourg
# Processing record 16 of set 10 | osinki
# Processing record 17 of set 10 | cortez
# Processing record 18 of set 10 | naryan-mar
# Processing record 19 of set 10 | forestville
# Processing record 20 of set 10 | poyarkovo
# Processing record 21 of set 10 | baie-comeau
# Processing record 22 of set 10 | vengerovo
# Processing record 23 of set 10 | varhaug
# Processing record 24 of set 10 | kazalinsk
# City not found. Skipping kazalinsk
# Processing record 25 of set 10 | cedar city
# Processing record 26 of set 10 | rozkishne
# Processing record 27 of set 10 | niederfeulen
# Processing record 28 of set 10 | camargo
# Processing record 29 of set 10 | jutai
# Processing record 30 of set 10 | tambura
# Processing record 31 of set 10 | mogadishu
# Processing record 32 of set 10 | pueblo nuevo
# Processing record 33 of set 10 | sigiriya
# Processing record 34 of set 10 | palabuhanratu
# City not found. Skipping palabuhanratu
# Processing record 35 of set 10 | sabha
# Processing record 36 of set 10 | livingston
# Processing record 37 of set 10 | victor harbor
# Processing record 38 of set 10 | sabzevar
# Processing record 39 of set 10 | enshi
# Processing record 40 of set 10 | lavrentiya
# Processing record 41 of set 10 | asau
# Processing record 42 of set 10 | san carlos de bariloche
# Processing record 43 of set 10 | dunedin
# Processing record 44 of set 10 | tutla
# City not found. Skipping tutla
# Processing record 45 of set 10 | westport
# Processing record 46 of set 10 | assiniboia
# Processing record 47 of set 10 | lafia
# Processing record 48 of set 10 | tchaourou
# Processing record 49 of set 10 | arandis
# Processing record 50 of set 10 | usinsk
# Processing record 1 of set 11 | orange cove
# Processing record 2 of set 11 | xanxere
# Processing record 3 of set 11 | marcona
# City not found. Skipping marcona
# Processing record 4 of set 11 | floro
# Processing record 5 of set 11 | antalaha
# Processing record 6 of set 11 | loukhi
# Processing record 7 of set 11 | nkowakowa
# Processing record 8 of set 11 | oltu
# Processing record 9 of set 11 | tumpat
# Processing record 10 of set 11 | twin falls
# Processing record 11 of set 11 | ust-nera
# Processing record 12 of set 11 | vestmanna
# Processing record 13 of set 11 | kununurra
# Processing record 14 of set 11 | cilegon
# Processing record 15 of set 11 | chizhou
# Processing record 16 of set 11 | nelson bay
# Processing record 17 of set 11 | anito
# Processing record 18 of set 11 | komsomolets
# Processing record 19 of set 11 | college
# Processing record 20 of set 11 | omboue
# Processing record 21 of set 11 | raga
# Processing record 22 of set 11 | iquique
# Processing record 23 of set 11 | zalantun
# Processing record 24 of set 11 | carberry
# Processing record 25 of set 11 | zhigansk
# Processing record 26 of set 11 | haapsalu
# Processing record 27 of set 11 | oriximina
# Processing record 28 of set 11 | touros
# Processing record 29 of set 11 | leshukonskoye
# Processing record 30 of set 11 | dalen
# Processing record 31 of set 11 | dera bugti
# Processing record 32 of set 11 | agirish
# Processing record 33 of set 11 | margate
# Processing record 34 of set 11 | sioux lookout
# Processing record 35 of set 11 | ust-kamchatsk
# City not found. Skipping ust-kamchatsk
# Processing record 36 of set 11 | sobolevo
# Processing record 37 of set 11 | catarman
# Processing record 38 of set 11 | henderson
# Processing record 39 of set 11 | santiago del estero
# Processing record 40 of set 11 | pacific grove
# Processing record 41 of set 11 | saint-francois
# Processing record 42 of set 11 | tarko-sale
# Processing record 43 of set 11 | rawah
# Processing record 44 of set 11 | buariki
# City not found. Skipping buariki
# Processing record 45 of set 11 | catuday
# Processing record 46 of set 11 | micheweni
# Processing record 47 of set 11 | porirua
# Processing record 48 of set 11 | conde
# Processing record 49 of set 11 | sulangan
# Processing record 50 of set 11 | kerema
# Processing record 1 of set 12 | butte
# Processing record 2 of set 12 | rincon
# Processing record 3 of set 12 | dargaville
# Processing record 4 of set 12 | butler
# Processing record 5 of set 12 | eyl
# Processing record 6 of set 12 | beloha
# Processing record 7 of set 12 | zaliznychne
# Processing record 8 of set 12 | comodoro rivadavia
# Processing record 9 of set 12 | kalmunai
# Processing record 10 of set 12 | hami
# Processing record 11 of set 12 | atambua
# Processing record 12 of set 12 | bay city
# Processing record 13 of set 12 | bajo baudo
# City not found. Skipping bajo baudo
# Processing record 14 of set 12 | te anau
# Processing record 15 of set 12 | salym
# Processing record 16 of set 12 | jiblah
# Processing record 17 of set 12 | samalaeulu
# City not found. Skipping samalaeulu
# Processing record 18 of set 12 | tuggurt
# City not found. Skipping tuggurt
# Processing record 19 of set 12 | the pas
# Processing record 20 of set 12 | severomuysk
# Processing record 21 of set 12 | ballina
# Processing record 22 of set 12 | puerto ayacucho
# Processing record 23 of set 12 | marquette
# Processing record 24 of set 12 | manaus
# Processing record 25 of set 12 | gravelbourg
# Processing record 26 of set 12 | padang
# Processing record 27 of set 12 | goderich
# Processing record 28 of set 12 | lolodorf
# Processing record 29 of set 12 | atar
# Processing record 30 of set 12 | batticaloa
# Processing record 31 of set 12 | tateyama
# Processing record 32 of set 12 | labutta
# City not found. Skipping labutta
# Processing record 33 of set 12 | roma
# Processing record 34 of set 12 | nelson
# Processing record 35 of set 12 | umzimvubu
# City not found. Skipping umzimvubu
# ---------------------------
# Data retrieval complete
# ---------------------------

# %%
len(city_data)
# Out:
# 532

# %%
city_data[-1]
# Out:
# {'City': 'nelson',
#  'Lat': -41.2833,
#  'Lng': 173.2833,
#  'Max Temp': 57.79,
#  'Humidity': 90,
#  'Cloudiness': 100,
#  'Wind Speed': 3,
#  'Country': 'NZ',
#  'Date': '2021-09-13 01:27:51'}

# %%
# convert list to DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port hawkesbury  45.6169  -61.3485     67.17        84          75
# 1            kapaa  22.0752 -159.3190     84.52        68          40
# 2             lata  40.1629   -8.3327     66.81        82         100
# 3        hithadhoo  -0.6000   73.0833     83.19        72          68
# 4        busselton -33.6500  115.3333     58.05        71          14
# 5        ilulissat  69.2167  -51.1000     30.22        64          75
# 6        san pedro  14.3500  121.0167     84.34        81          75
# 7          ushuaia -54.8000  -68.3000     38.86        65          40
# 8      port alfred -33.5906   26.8910     64.00        85         100
# 9       sao filipe  14.8961  -24.4956     79.05        80          95
#
#    Wind Speed Country                 Date
# 0        8.01      CA  2021-09-13 01:25:10
# 1        4.00      US  2021-09-13 01:25:11
# 2        3.18      PT  2021-09-13 01:25:11
# 3        9.95      MV  2021-09-13 01:25:11
# 4        5.30      AU  2021-09-13 01:25:12
# 5       10.36      GL  2021-09-13 01:25:12
# 6        1.14      PH  2021-09-13 01:25:12
# 7       27.63      AR  2021-09-13 01:25:13
# 8       10.18      ZA  2021-09-13 01:25:13
# 9        8.37      CV  2021-09-13 01:25:13

# %%
city_data_df.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0  port hawkesbury      CA  2021-09-13 01:25:10  45.6169  -61.3485     67.17
# 1            kapaa      US  2021-09-13 01:25:11  22.0752 -159.3190     84.52
# 2             lata      PT  2021-09-13 01:25:11  40.1629   -8.3327     66.81
# 3        hithadhoo      MV  2021-09-13 01:25:11  -0.6000   73.0833     83.19
# 4        busselton      AU  2021-09-13 01:25:12 -33.6500  115.3333     58.05
# 5        ilulissat      GL  2021-09-13 01:25:12  69.2167  -51.1000     30.22
# 6        san pedro      PH  2021-09-13 01:25:12  14.3500  121.0167     84.34
# 7          ushuaia      AR  2021-09-13 01:25:13 -54.8000  -68.3000     38.86
# 8      port alfred      ZA  2021-09-13 01:25:13 -33.5906   26.8910     64.00
# 9       sao filipe      CV  2021-09-13 01:25:13  14.8961  -24.4956     79.05
#
#    Humidity  Cloudiness  Wind Speed
# 0        84          75        8.01
# 1        68          40        4.00
# 2        82         100        3.18
# 3        72          68        9.95
# 4        71          14        5.30
# 5        64          75       10.36
# 6        81          75        1.14
# 7        65          40       27.63
# 8        85         100       10.18
# 9        80          95        8.37

# %%
# create the output file (csv)
output_data_file = 'weather_data/cities.csv'
# export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label='City_ID')
